# %%
import numpy as np 
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
df=pd.read_csv('Sales_data.csv')
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# # Item_Identifier

# %%
df['Item_Identifier'].value_counts()
# Out:
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
#          ..
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, Length: 1559, dtype: int64

# %% [raw]
# So many unique values with object data type. This feature is not important for data analysis so drop it.

# %%
df.drop('Item_Identifier',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                7060 non-null   float64
#  1   Item_Fat_Content           8523 non-null   object
#  2   Item_Visibility            8523 non-null   float64
#  3   Item_Type                  8523 non-null   object
#  4   Item_MRP                   8523 non-null   float64
#  5   Outlet_Identifier          8523 non-null   object
#  6   Outlet_Establishment_Year  8523 non-null   int64
#  7   Outlet_Size                6113 non-null   object
#  8   Outlet_Location_Type       8523 non-null   object
#  9   Outlet_Type                8523 non-null   object
#  10  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 732.6+ KB

# %% [markdown]
# # Item_Weight

# %%
df['Item_Weight'].isna().sum()
# Out:
# 1463

# %%
sns.kdeplot(x=df['Item_Weight'])
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Density'>

# %%
df['Item_Weight'].mean()
# Out:
# 12.857645184135976

# %%
df['Item_Weight'].mode()[0]
# Out:
# 12.15

# %%
df['Item_Weight'].median()
# Out:
# 12.6

# %%
df['Item_Weight'].fillna(df['Item_Weight'].mean(),inplace=True)

# %%
df['Item_Weight'].isna().sum()
# Out:
# 0

# %%
sns.kdeplot(x=df['Item_Weight'])
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Density'>

# %%
sns.boxplot(x=df['Item_Weight'])
# Out:
# <AxesSubplot:xlabel='Item_Weight'>

# %% [raw]
# no outliers are detected

# %% [markdown]
# # Item_Fat_Content

# %%
df['Item_Fat_Content'].isna().sum()
# Out:
# 0

# %%
df['Item_Fat_Content'].value_counts().to_dict()
# Out:
# {'Low Fat': 5089, 'Regular': 2889, 'LF': 316, 'reg': 117, 'low fat': 112}

# %%
df['Item_Fat_Content'].replace({'Low Fat': 0, 'Regular': 1, 'LF': 0, 'reg': 1, 'low fat': 0},inplace=True)

# %%
df['Item_Fat_Content'].value_counts().to_dict()
# Out:
# {0: 5517, 1: 3006}

# %%
sns.countplot(x=df['Item_Fat_Content'])
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='count'>

# %% [markdown]
# # Item_Visibility

# %%
df['Item_Visibility'].isna().sum()
# Out:
# 0

# %%
sns.kdeplot(x=df['Item_Visibility'])
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Density'>

# %%
sns.boxplot(x=df['Item_Visibility'])
# Out:
# <AxesSubplot:xlabel='Item_Visibility'>

# %%
### cuberoot transform
df['Item_Visibility']=df['Item_Visibility']**(1/3)

# %%
plt.scatter(df['Item_Visibility'],df['Item_Weight'])

# %% [markdown]
# # Item_Type

# %%
df['Item_Type'].value_counts().to_dict()
# Out:
# {'Fruits and Vegetables': 1232,
#  'Snack Foods': 1200,
#  'Household': 910,
#  'Frozen Foods': 856,
#  'Dairy': 682,
#  'Canned': 649,
#  'Baking Goods': 648,
#  'Health and Hygiene': 520,
#  'Soft Drinks': 445,
#  'Meat': 425,
#  'Breads': 251,
#  'Hard Drinks': 214,
#  'Others': 169,
#  'Starchy Foods': 148,
#  'Breakfast': 110,
#  'Seafood': 64}

# %%
df['Item_Type'].isna().sum()
# Out:
# 0

# %%
df_item_type=pd.get_dummies(df['Item_Type'],prefix='Item_Type',drop_first=True)
df_item_type
# Out:
#       Item_Type_Breads  Item_Type_Breakfast  Item_Type_Canned  \
# 0                    0                    0                 0
# 1                    0                    0                 0
# 2                    0                    0                 0
# 3                    0                    0                 0
# 4                    0                    0                 0
# ...                ...                  ...               ...
# 8518                 0                    0                 0
# 8519                 0                    0                 0
# 8520                 0                    0                 0
# 8521                 0                    0                 0
# 8522                 0                    0                 0
#
#       Item_Type_Dairy  Item_Type_Frozen Foods  \
# 0                   1                       0
# 1                   0                       0
# 2                   0                       0
# ...

# %%
plt.figure(figsize=(50,20))
sns.countplot(x=df['Item_Type'])
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='count'>

# %% [markdown]
# # Item_MRP

# %%
df['Item_MRP'].isna().sum()
# Out:
# 0

# %%
sns.boxplot(x=df['Item_MRP'])
# Out:
# <AxesSubplot:xlabel='Item_MRP'>

# %%
sns.kdeplot(x=df['Item_MRP'])
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Density'>

# %%
plt.scatter(df['Item_MRP'],df['Item_Weight'])

# %% [markdown]
# # Outlet_Identifier

# %%
df['Outlet_Identifier'].value_counts()
# Out:
# OUT027    935
# OUT013    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64

# %%
df['Outlet_Identifier'].isna().sum()
# Out:
# 0

# %%
df.drop('Outlet_Identifier',axis=1,inplace=True)

# %% [markdown]
# # Outlet_Establishment_Year

# %%
df['Outlet_Establishment_Year'].isna().sum()
# Out:
# 0

# %%
df['Outlet_Establishment_Year'].value_counts()
# Out:
# 1985    1463
# 1987     932
# 1999     930
# 1997     930
# 2004     930
# 2002     929
# 2009     928
# 2007     926
# 1998     555
# Name: Outlet_Establishment_Year, dtype: int64

# %%
df['Outlet_Establishment_Year']=df['Outlet_Establishment_Year']-2022

# %%
df['Outlet_Establishment_Year']=(df['Outlet_Establishment_Year']**2)**0.5

# %%
df['Outlet_Establishment_Year'].value_counts()
# Out:
# 37.0    1463
# 35.0     932
# 23.0     930
# 25.0     930
# 18.0     930
# 20.0     929
# 13.0     928
# 15.0     926
# 24.0     555
# Name: Outlet_Establishment_Year, dtype: int64

# %%
sns.kdeplot(x=df['Outlet_Establishment_Year'])
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='Density'>

# %%
sns.boxplot(x=df['Outlet_Establishment_Year'])
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year'>

# %% [markdown]
# # Outlet_Size

# %%
df['Outlet_Size'].isna().sum()
# Out:
# 2410

# %%
df['Outlet_Size'].mode()[0]
# Out:
# 'Medium'

# %%
df['Outlet_Size'].fillna(df['Outlet_Size'].mode()[0],inplace=True)

# %%
sns.countplot(x=df['Outlet_Size'])
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='count'>

# %%
df_outlet_size=pd.get_dummies(df['Outlet_Size'],prefix='Outlet_Size',drop_first=True)
df_outlet_size
# Out:
#       Outlet_Size_Medium  Outlet_Size_Small
# 0                      1                  0
# 1                      1                  0
# 2                      1                  0
# 3                      1                  0
# 4                      0                  0
# ...                  ...                ...
# 8518                   0                  0
# 8519                   1                  0
# 8520                   0                  1
# 8521                   1                  0
# 8522                   0                  1
#
# [8523 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                8523 non-null   float64
#  1   Item_Fat_Content           8523 non-null   int64
#  2   Item_Visibility            8523 non-null   float64
#  3   Item_Type                  8523 non-null   object
#  4   Item_MRP                   8523 non-null   float64
#  5   Outlet_Establishment_Year  8523 non-null   float64
#  6   Outlet_Size                8523 non-null   object
#  7   Outlet_Location_Type       8523 non-null   object
#  8   Outlet_Type                8523 non-null   object
#  9   Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 666.0+ KB

# %% [markdown]
# # Outlet_Location_Type

# %%
df['Outlet_Location_Type'].isna().sum()
# Out:
# 0

# %%
df['Outlet_Location_Type'].value_counts()
# Out:
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64

# %%
df_olt=pd.get_dummies(df['Outlet_Location_Type'],prefix='Outlet_Location_Type',drop_first=True)
df_olt
# Out:
#       Outlet_Location_Type_Tier 2  Outlet_Location_Type_Tier 3
# 0                               0                            0
# 1                               0                            1
# 2                               0                            0
# 3                               0                            1
# 4                               0                            1
# ...                           ...                          ...
# 8518                            0                            1
# 8519                            1                            0
# 8520                            1                            0
# 8521                            0                            1
# 8522                            0                            0
#
# [8523 rows x 2 columns]

# %%
sns.countplot(x=df['Outlet_Location_Type'])
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='count'>

# %% [markdown]
# # Outlet_Type

# %%
df['Outlet_Type'].isna().sum()
# Out:
# 0

# %%
df['Outlet_Type'].value_counts()
# Out:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
df_otype=pd.get_dummies(df['Outlet_Type'],prefix='Outlet_Type',drop_first=True)
df_otype
# Out:
#       Outlet_Type_Supermarket Type1  Outlet_Type_Supermarket Type2  \
# 0                                 1                              0
# 1                                 0                              1
# 2                                 1                              0
# 3                                 0                              0
# 4                                 1                              0
# ...                             ...                            ...
# 8518                              1                              0
# 8519                              1                              0
# 8520                              1                              0
# 8521                              0                              1
# 8522                              1                              0
#
#       Outlet_Type_Supermarket Type3
# 0                                 0
# 1                                 0
# 2                                 0
# ...

# %% [markdown]
# # Item_Outlet_Sales

# %%
df['Item_Outlet_Sales'].isna().sum()
# Out:
# 0

# %%
sns.kdeplot(x=df['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
sns.boxplot(x=df['Item_Outlet_Sales']**0.226)
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales'>

# %%
plt.scatter(df['Item_MRP'],df['Item_Outlet_Sales']**0.226)

# %%
#Transform
df['Item_Outlet_Sales']=df['Item_Outlet_Sales']**0.226

# %%
columns_to_remove=['Item_Type','Outlet_Size','Outlet_Location_Type','Outlet_Type']
df.drop(columns_to_remove,axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                8523 non-null   float64
#  1   Item_Fat_Content           8523 non-null   int64
#  2   Item_Visibility            8523 non-null   float64
#  3   Item_MRP                   8523 non-null   float64
#  4   Outlet_Establishment_Year  8523 non-null   float64
#  5   Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 399.6 KB

# %%
sns.pairplot(df)

# %%
delete_rows=df.loc[(df['Item_Visibility']<0.1)]
delete_rows.index.to_list()
# Out:
# [3,
#  4,
#  5,
#  10,
#  32,
#  33,
#  46,
#  60,
#  72,
#  79,
#  107,
#  114,
#  144,
#  156,
#  175,
#  212,
#  214,
#  216,
#  219,
#  228,
#  307,
#  349,
#  370,
#  379,
#  386,
#  388,
#  411,
#  423,
#  447,
#  472,
#  478,
#  482,
#  499,
#  500,
#  505,
#  520,
#  535,
#  545,
#  559,
#  576,
#  596,
#  600,
#  602,
#  613,
#  623,
#  633,
#  651,
#  677,
#  687,
#  722,
#  737,
#  741,
#  747,
#  781,
#  791,
#  792,
#  801,
#  802,
#  838,
#  840,
#  844,
#  900,
#  906,
#  943,
#  955,
#  968,
#  1063,
#  1074,
#  1094,
#  1113,
#  1118,
#  1120,
#  1143,
#  1145,
#  1146,
#  1179,
#  1197,
#  1212,
#  1243,
#  1263,
#  1292,
#  1326,
#  1335,
#  1346,
#  1350,
#  1351,
#  1390,
#  1391,
#  1405,
#  1418,
#  1450,
#  1454,
#  1463,
#  1467,
#  1472,
#  1483,
#  1486,
#  1505,
#  1508,
#  1511,
#  1537,
#  1585,
#  1623,
#  1633,
#  1636,
#  1643,
#  1649,
#  1665,
#  1691,
#  1693,
#  1727,
#  1758,
#  1760,
#  1761,
#  1768,
#  1782,
#  1809,
#  1851,
#  1862,
# ...

# %%
df.drop(delete_rows.index.to_list(),axis=0,inplace=True)

# %%
df
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0        9.300000                 0         0.252232  249.8092
# 1        5.920000                 1         0.268136   48.2692
# 2       17.500000                 0         0.255913  141.6180
# 6       13.650000                 1         0.233562   57.6588
# 7       12.857645                 0         0.503272  107.7622
# ...           ...               ...              ...       ...
# 8518     6.865000                 0         0.384362  214.5218
# 8519     8.380000                 1         0.360838  108.1570
# 8520    10.600000                 0         0.327686   85.1224
# 8521     7.210000                 1         0.525625  103.1332
# 8522    14.800000                 0         0.355368   75.4670
#
#       Outlet_Establishment_Year  Item_Outlet_Sales
# 0                          23.0           6.417137
# 1                          13.0           3.964431
# 2                          23.0           5.632405
# ...

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                            Item_Weight  Item_Fat_Content  Item_Visibility  \
# Item_Weight                   1.000000         -0.021650        -0.018678
# Item_Fat_Content             -0.021650          1.000000         0.057060
# Item_Visibility              -0.018678          0.057060         1.000000
# Item_MRP                      0.026932          0.009221        -0.001735
# Outlet_Establishment_Year     0.008910         -0.004672         0.063330
# Item_Outlet_Sales             0.010326          0.016246        -0.164054
#
#                            Item_MRP  Outlet_Establishment_Year  \
# Item_Weight                0.026932                   0.008910
# Item_Fat_Content           0.009221                  -0.004672
# Item_Visibility           -0.001735                   0.063330
# Item_MRP                   1.000000                  -0.003266
# Outlet_Establishment_Year -0.003266                   1.000000
# Item_Outlet_Sales          0.539429                  -0.045967
#
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>
